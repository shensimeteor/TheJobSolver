# %%
from pyspark import SparkConf, SparkContext
from pyspark.mllib.feature import HashingTF
from pyspark.mllib.feature import IDF
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf
from pyspark.ml.feature import HashingTF, IDF, Tokenizer
from pyspark.ml.feature import StringIndexer
from pyspark.ml import Pipeline
from pyspark.ml.feature import CountVectorizer
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.feature import CountVectorizerModel
from pyspark.sql.types import ArrayType, FloatType, StringType, DoubleType
import heapq
import operator

# %%
spark = SparkSession.builder.appName("tfidf").config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.11:2.2.0").getOrCreate()
df =  spark.read.format("com.mongodb.spark.sql.DefaultSource").option("uri","mongodb://user:indeedjob@ec2-52-55-205-188.compute-1.amazonaws.com/appDatabase.jobs").load()
#(train_set, val_set, test_set) = df.randomSplit([0.98, 0.01, 0.01], seed = 2000)
data = df.select('_id','job_title','job_description_cleaned')
#hashtf = HashingTF(numFeatures=2**16, inputCol="job_description_cleaned", outputCol='tf')
countVectors = CountVectorizer(inputCol="job_description_cleaned", outputCol="tf", vocabSize=2**16, minDF=5)
idf = IDF(inputCol='tf', outputCol="features", minDocFreq=5) #minDocFreq: remove sparse terms
#label_stringIdx = StringIndexer(inputCol = "job_title", outputCol = "label")
pipeline = Pipeline(stages=[countVectors,idf])
pipelineFit = pipeline.fit(data)
dataset = pipelineFit.transform(data)
dataset.show()
# Out:
# +----------------+--------------------+-----------------------+--------------------+--------------------+
# |             _id|           job_title|job_description_cleaned|                  tf|            features|
# +----------------+--------------------+-----------------------+--------------------+--------------------+
# |000004eaddcb4ae7|Research Account ...|   [current, employe...|(65536,[0,1,5,7,1...|(65536,[0,1,5,7,1...|
# |000016cd690914cd|Recruitment Coord...|   [temporaryrespons...|(65536,[1,4,9,12,...|(65536,[1,4,9,12,...|
# |0000c4848b2b952d|Electrical Contro...|   [yearsr, electric...|(65536,[0,1,2,3,4...|(65536,[0,1,2,3,4...|
# |0000ef8321b7ed98|Product Developme...|   [like, join, fort...|(65536,[0,1,2,3,4...|(65536,[0,1,2,3,4...|
# |00010db38efb0901| Systems Engineer II|   [overview, new, i...|(65536,[0,1,2,4,8...|(65536,[0,1,2,4,8...|
# |00015de142c7152f|Marketing Data an...|   [role, looking, m...|(65536,[0,1,2,3,4...|(65536,[0,1,2,3,4...|
# |00019ff96d26f26a| Procurement Analyst|   [yeardesired, pro...|(65536,[1,3,5,14,...|(65536,[1,3,5,14,...|
# |0001dce0efd3f0bc|Analyst, Customer...|   [job, summarysupp...|(65536,[0,1,3,4,5...|(65536,[0,1,3,4,5...|
# |000244a61a7f5b65|Integration Analy...|   [job, description...|(65536,[0,1,3,5,9...|(65536,[0,1,3,5,9...|
# |00026aa825635937|        iOS Engineer|   [looking, years, ...|(65536,[0,3,4,5,7...|(65536,[0,3,4,5,7...|
# |000288d7f41cf2a7|      Superintendent|   [desired, osha, p...|(65536,[0,1,4,5,9...|(65536,[0,1,4,5,9...|
# |0002b98bc8693187|      Sr. IT Analyst|   [summary, sr, ana...|(65536,[0,1,2,3,5...|(65536,[0,1,2,3,5...|
# |0002e3118a77d010|Forging Operator ...|   [shift, nd, posit...|(65536,[0,1,2,4,5...|(65536,[0,1,2,4,5...|
# |0003851037c87e69|Sr. Software Deve...|   [oversee, design,...|(65536,[0,1,2,5,8...|(65536,[0,1,2,5,8...|
# |00039398e0ed3035|Sr.Spec Infrastrc...|   [desired, cheflin...|(65536,[0,1,2,3,4...|(65536,[0,1,2,3,4...|
# |0003cd55a409f96c|Director I - Prog...|   [program, manager...|(65536,[0,2,3,4,5...|(65536,[0,2,3,4,5...|
# |0003d5d6ac6cb8ce|Junior CRM Busine...|   [career, new, yor...|(65536,[0,1,2,3,4...|(65536,[0,1,2,3,4...|
# |0003ef5368adfe5d|Sr. Systems Admin...|   [position, sr, sy...|(65536,[0,1,3,5,7...|(65536,[0,1,3,5,7...|
# |00042fd79df4f286|Chief Program & I...|   [desired, program...|(65536,[0,1,2,3,4...|(65536,[0,1,2,3,4...|
# |00051210c021f804|Clinic Administra...|   [desired, rnmanag...|(65536,[0,3,5,6,7...|(65536,[0,3,5,6,7...|
# +----------------+--------------------+-----------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
stages = pipelineFit.stages
vectorizers = [s for s in stages if isinstance(s, CountVectorizerModel)]
vectorizers[0].vocabulary
# Out:
# ['experience',
#  'work',
#  'will',
#  'data',
#  'team',
#  'skills',
#  'business',
#  'management',
#  'development',
#  'ability',
#  'systems',
#  'required',
#  'support',
#  'software',
#  'years',
#  'technical',
#  'design',
#  'knowledge',
#  'requirements',
#  'including',
#  'engineering',
#  'information',
#  'new',
#  'product',
#  'services',
#  'quality',
#  'working',
#  'solutions',
#  'position',
#  'job',
#  'project',
#  'must',
#  'environment',
#  'related',
#  'degree',
#  'technology',
#  'system',
#  'customer',
#  'strong',
#  'provide',
#  'security',
#  'company',
#  'analysis',
#  'process',
#  'responsibilities',
#  'service',
#  'develop',
#  'andor',
#  'customers',
#  'us',
#  'preferred',
#  'qualifications',
#  'communication',
#  'projects',
#  'ensure',
#  'status',
#  'computer',
#  'opportunity',
#  'products',
#  'may',
#  'tools',
#  'within',
#  'teams',
#  'performance',
#  'program',
#  'applications',
#  'time',
#  'test',
#  'application',
#  'responsible',
#  'employment',
#  'testing',
#  'training',
#  'maintain',
#  'education',
#  'duties',
#  'understanding',
#  'processes',
#  'science',
#  'using',
#  'level',
#  'perform',
#  'role',
#  'procedures',
#  'research',
#  'employees',
#  'health',
#  'operations',
#  'technologies',
#  'network',
#  'include',
#  'issues',
#  'field',
#  'able',
#  'professional',
#  'care',
#  'engineer',
#  'office',
#  'clients',
#  'needs',
#  'one',
#  'equal',
#  'staff',
#  'use',
#  'industry',
#  'help',
#  'high',
#  'reports',
#  'across',
#  'people',
#  'complex',
#  'excellent',
#  'bachelors',
#  'written',
#  'best',
#  'activities',
#  'standards',
#  'employer',
#  'equipment',
#  'financial',
#  'manage',
#  'programs',
#  'can',
#  'sales',
#  'problems',
#  'based',
#  'client',
#  'minimum',
#  'desired',
#  'national',
#  'internal',
#  'medical',
#  'opportunities',
#  'benefits',
#  'build',
#  'disability',
#  'lead',
#  'etc',
#  'manager',
#  'assigned',
#  'make',
#  'organization',
#  'multiple',
#  'practices',
#  'leadership',
#  'developing',
#  'provides',
#  'meet',
#  'plans',
#  'applicants',
#  'key',
#  'control',
#  'documentation',
#  'create',
#  'part',
#  'planning',
#  'assist',
#  'functions',
#  'also',
#  'global',
#  'candidate',
#  'appropriate',
#  'implementation',
#  'compliance',
#  'building',
#  'employee',
#  'looking',
#  'department',
#  'engineers',
#  'equivalent',
#  'microsoft',
#  'plan',
#  'gender',
#  'providing',
#  'plus',
#  'cloud',
#  'reporting',
#  'effectively',
#  'senior',
#  'review',
#  'members',
#  'state',
#  'identify',
#  'maintenance',
#  'apply',
#  'web',
#  'protected',
#  'orientation',
#  'following',
#  'production',
#  'learning',
#  'year',
#  'without',
#  'world',
#  'essential',
#  'join',
#  'various',
#  'safety',
#  'infrastructure',
#  'travel',
#  'enterprise',
#  'drive',
#  'needed',
#  'color',
#  'analytical',
#  'veteran',
#  'current',
#  'policies',
#  'areas',
#  'marketing',
#  'highly',
#  'race',
#  'qualified',
#  'user',
#  'leading',
#  'origin',
#  'analytics',
#  'results',
#  'tasks',
#  'communicate',
#  'delivery',
#  'life',
#  'religion',
#  'expertise',
#  'vision',
#  'code',
#  'description',
#  'integration',
#  'sexual',
#  'advanced',
#  'clinical',
#  'please',
#  'group',
#  'problem',
#  'improve',
#  'identity',
#  'demonstrated',
#  'understand',
#  'database',
#  'career',
#  'architecture',
#  'federal',
#  'programming',
#  'action',
#  'assurance',
#  'individual',
#  'deliver',
#  'implement',
#  'analyst',
#  'relevant',
#  'basic',
#  'goals',
#  'risk',
#  'effective',
#  'sql',
#  'external',
#  'manufacturing',
#  'administration',
#  'learn',
#  'individuals',
#  'verbal',
#  'change',
#  'good',
#  'access',
#  'physical',
#  'platform',
#  'age',
#  'necessary',
#  'general',
#  'mission',
#  'candidates',
#  'operating',
#  'improvement',
#  'hardware',
#  'need',
#  'successful',
#  'day',
#  'digital',
#  'success',
#  'resources',
#  'relationships',
#  'functional',
#  'center',
#  'operational',
#  'others',
#  'community',
#  'analyze',
#  'innovative',
#  'market',
#  'sex',
#  'growth',
#  'supporting',
#  'local',
#  'existing',
#  'area',
#  'insurance',
#  'participate',
#  'strategic',
#  'partners',
#  'background',
#  'specific',
#  'requires',
#  'competitive',
#  'diverse',
#  'patient',
#  'documents',
#  'managing',
#  'impact',
#  'critical',
#  'complete',
#  'certification',
#  'regard',
#  'full',
#  'additional',
#  'focus',
#  'automation',
#  'large',
#  'value',
#  'variety',
#  'every',
#  'techniques',
#  'applicable',
#  'agile',
#  'future',
#  'solving',
#  'strategy',
#  'monitoring',
#  'works',
#  'server',
#  'excel',
#  'seeking',
#  'like',
#  'type',
#  'closely',
#  'basis',
#  'offer',
#  'c',
#  'organizational',
#  'eg',
#  'states',
#  'culture',
#  'direct',
#  'limited',
#  'least',
#  'location',
#  'order',
#  'schedule',
#  'healthcare',
#  'personnel',
#  'receive',
#  'maintaining',
#  'clearance',
#  'levels',
#  'processing',
#  'hours',
#  'includes',
#  'communications',
#  'reviews',
#  'committed',
#  'take',
#  'changes',
#  'electrical',
#  'law',
#  'government',
#  'primary',
#  'innovation',
#  'java',
#  'specifications',
#  'school',
#  'stakeholders',
#  'independently',
#  'timely',
#  'managers',
#  'daily',
#  'great',
#  'meetings',
#  'maintains',
#  'writing',
#  'decisions',
#  'solution',
#  'cost',
#  'policy',
#  'materials',
#  'objectives',
#  'intelligence',
#  'continuous',
#  'collaborate',
#  'proven',
#  'interpersonal',
#  'consideration',
#  'record',
#  'member',
#  'machine',
#  'users',
#  'public',
#  'report',
#  'concepts',
#  'companies',
#  'methods',
#  'university',
#  'troubleshooting',
#  'leader',
#  'document',
#  'personal',
#  'regulations',
#  'available',
#  'performs',
#  'core',
#  'creating',
#  'performing',
#  'construction',
#  'initiatives',
#  'paid',
#  'manner',
#  'united',
#  'ms',
#  'assistance',
#  'summary',
#  'around',
#  'platforms',
#  'conduct',
#  'standard',
#  'making',
#  'patients',
#  'strategies',
#  'capabilities',
#  'configuration',
#  'fulltime',
#  'coordinate',
#  'growing',
#  'execution',
#  'partner',
#  'detail',
#  'windows',
#  'corporate',
#  'develops',
#  'director',
#  'throughout',
#  'environments',
#  'power',
#  'serve',
#  'recommendations',
#  'python',
#  'range',
#  'familiarity',
#  'track',
#  'mobile',
#  'finance',
#  'open',
#  'regulatory',
#  'active',
#  'designs',
#  'possess',
#  'end',
#  'site',
#  'potential',
#  'challenges',
#  'achieve',
#  'models',
#  'proficiency',
#  'requests',
#  'collaboration',
#  'contact',
#  'responsibility',
#  'efforts',
#  'direction',
#  'subject',
#  'comprehensive',
#  'principles',
#  'organizations',
#  'k',
#  'ensuring',
#  'expert',
#  'used',
#  'ideas',
#  'monitor',
#  'compensation',
#  'creative',
#  'solve',
#  'supervision',
#  'components',
#  'top',
#  'better',
#  'overall',
#  'offers',
#  'big',
#  'resolve',
#  'modeling',
#  'masters',
#  'commercial',
#  'set',
#  'accounting',
#  'abilities',
#  'established',
#  'online',
#  'experienced',
#  'implementing',
#  'positive',
#  'passion',
#  'oral',
#  'locations',
#  'prepare',
#  'special',
#  'guidance',
#  'college',
#  'integrity',
#  'consulting',
#  'aws',
#  'enable',
#  'hiring',
#  'require',
#  'small',
#  'inc',
#  'unit',
#  'directly',
#  'attention',
#  'values',
#  'nursing',
#  'want',
#  'deep',
#  'human',
#  'trends',
#  'way',
#  'currently',
#  'practice',
#  'conditions',
#  'delivering',
#  'collaborative',
#  'records',
#  'language',
#  'linux',
#  'major',
#  'right',
#  'assists',
#  'dental',
#  'define',
#  'word',
#  'content',
#  'designing',
#  'mechanical',
#  'contract',
#  'controls',
#  'students',
#  'dynamic',
#  'evaluate',
#  'databases',
#  'administrator',
#  'reasonable',
#  'discipline',
#  'place',
#  'groups',
#  'prior',
#  'package',
#  'disabilities',
#  'execute',
#  'ongoing',
#  'laboratory',
#  'demonstrate',
#  'supports',
#  'professionals',
#  'diversity',
#  'family',
#  'deployment',
#  'accurate',
#  'flexible',
#  'grow',
#  'accordance',
#  'regarding',
#  'unique',
#  'contribute',
#  'successfully',
#  'account',
#  'features',
#  'follow',
#  'networks',
#  'facility',
#  'ensures',
#  'determine',
#  'completion',
#  'networking',
#  'social',
#  'first',
#  'detailed',
#  'act',
#  'focused',
#  'resolution',
#  'salary',
#  'get',
#  'methodologies',
#  'email',
#  'per',
#  'marital',
#  'devices',
#  'departments',
#  'associates',
#  'developer',
#  'experiences',
#  'person',
#  'facilities',
#  'budget',
#  'agency',
#  'administrative',
#  'fastpaced',
#  'agencies',
#  'driving',
#  'scope',
#  'metrics',
#  'vendors',
#  'considered',
#  'developers',
#  'portfolio',
#  'languages',
#  'passionate',
#  'priorities',
#  'two',
#  'positions',
#  'associated',
#  'proficient',
#  'evaluation',
#  'similar',
#  'participates',
#  'scale',
#  'guidelines',
#  'bring',
#  'excellence',
#  'together',
#  'commitment',
#  'handson',
#  'wide',
#  'solid',
#  'statistical',
#  'storage',
#  'obtain',
#  'regular',
#  'insights',
#  'worlds',
#  'many',
#  'tests',
#  'automated',
#  'aspects',
#  'home',
#  'certifications',
#  'energy',
#  'quickly',
#  'improvements',
#  'resource',
#  'helping',
#  'different',
#  'international',
#  'ideal',
#  'operation',
#  'supply',
#  'upon',
#  'addition',
#  'write',
#  'pay',
#  'oriented',
#  'javascript',
#  'provider',
#  'visit',
#  'model',
#  'citizenship',
#  'presentation',
#  'establish',
#  'feedback',
#  'license',
#  'interface',
#  'assessment',
#  'line',
#  'efficient',
#  'electronic',
#  'present',
#  'hire',
#  'next',
#  'date',
#  'leaders',
#  'made',
#  'driven',
#  'events',
#  'bs',
#  'certified',
#  'consistent',
#  'qa',
#  'approach',
#  'skill',
#  'source',
#  'shift',
#  'protocols',
#  'function',
#  'exceptional',
#  'expected',
#  'space',
#  'coordination',
#  'cycle',
#  'matter',
#  'questions',
#  'tracking',
#  'military',
#  'prioritize',
#  'resume',
#  'located',
#  'media',
#  'laws',
#  'fast',
#  'oracle',
#  'annual',
#  'progress',
#  'drug',
#  'three',
#  'check',
#  'crossfunctional',
#  'thinking',
#  'largest',
#  'outside',
#  'assignments',
#  'accredited',
#  'accuracy',
#  'ie',
#  'efficiency',
#  'audit',
#  'coding',
#  'food',
#  'suite',
#  'firm',
#  'preparation',
#  'manages',
#  'setting',
#  'accounts',
#  'inventory',
#  'deadlines',
#  'lifecycle',
#  'leads',
#  'schedules',
#  'extensive',
#  'installation',
#  'analysts',
#  'hands',
#  'talent',
#  'meeting',
#  'markets',
#  'environmental',
#  'frameworks',
#  'talented',
#  'combination',
#  'distributed',
#  'analyzing',
#  'integrated',
#  'address',
#  'expectations',
#  'workplace',
#  'clear',
#  'material',
#  'dedicated',
#  'presentations',
#  'scripting',
#  'lives',
#  'proper',
#  'executive',
#  'changing',
#  'monthly',
#  'industrial',
#  'come',
#  'operate',
#  'validation',
#  'vendor',
#  'student',
#  'genetic',
#  'scientific',
#  'decision',
#  'defense',
#  'move',
#  'demands',
#  'know',
#  'overview',
#  'real',
#  'broad',
#  'businesses',
#  'enhance',
#  'interact',
#  'google',
#  'possible',
#  'applying',
#  'believe',
#  'division',
#  'cases',
#  'supervisor',
#  'veterans',
#  'provided',
#  'communities',
#  'accommodation',
#  'generation',
#  'revenue',
#  'identifying',
#  'deliverables',
#  'credit',
#  'san',
#  'legal',
#  'find',
#  'motivated',
#  'via',
#  'handle',
#  'safe',
#  'performed',
#  'share',
#  'just',
#  'utilizing',
#  'expression',
#  'point',
#  'cyber',
#  'common',
#  'actions',
#  'call',
#  'things',
#  'computing',
#  'associate',
#  'facilitate',
#  'tech',
#  'transportation',
#  'consumer',
#  'framework',
#  'workforce',
#  'studies',
#  'exciting',
#  'number',
#  'analyses',
#  'read',
#  'long',
#  'purpose',
#  'previous',
#  'exposure',
#  'verification',
#  'interest',
#  'instructions',
#  'sources',
#  'challenging',
#  'treatment',
#  'secure',
#  'collection',
#  'days',
#  'independent',
#  'chain',
#  'capital',
#  'higher',
#  'sap',
#  'five',
#  'eligibility',
#  'dod',
#  'o',
#  'see',
#  'hospital',
#  'benefit',
#  'actively',
#  'base',
#  'updates',
#  'according',
#  'demonstrates',
#  'significant',
#  'keep',
#  'creation',
#  'class',
#  'problemsolving',
#  'troubleshoot',
#  'interpret',
#  'ways',
#  'phone',
#  'offices',
#  'release',
#  'investment',
#  'accommodations',
#  'worldwide',
#  'companys',
#  'sets',
#  'risks',
#  'cisco',
#  'lab',
#  'proud',
#  'love',
#  'outcomes',
#  'optimization',
#  'request',
#  'drivers',
#  'initiative',
#  'sites',
#  'city',
#  'along',
#  'reach',
#  'powerpoint',
#  'specialist',
#  'now',
#  'important',
#  'highest',
#  'case',
#  'met',
#  'educational',
#  'providers',
#  'secret',
#  'close',
#  'lift',
#  'comfortable',
#  'amazon',
#  'orders',
#  'rd',
#  'makes',
#  'applicant',
#  'response',
#  'desire',
#  'situations',
#  'onsite',
#  'requirement',
#  'residents',
#  'eligible',
#  'servers',
#  'assessments',
#  'embedded',
#  'promote',
#  'submit',
#  'relationship',
#  'ownership',
#  'reliability',
#  'recognized',
#  'representative',
#  'algorithms',
#  'devops',
#  'completed',
#  'affirmative',
#  'statistics',
#  'mental',
#  'statement',
#  'audits',
#  'influence',
#  'investigation',
#  'details',
#  'respect',
#  'history',
#  'quantitative',
#  'north',
#  'brand',
#  'distribution',
#  'video',
#  'preferably',
#  'respond',
#  'assess',
#  'search',
#  'flow',
#  'visual',
#  'acquisition',
#  'become',
#  'coordinates',
#  'coverage',
#  'enjoy',
#  'balance',
#  'live',
#  'colleagues',
#  'utilize',
#  'd',
#  'satisfaction',
#  'interested',
#  'modern',
#  'clearly',
#  'scheduling',
#  'capacity',
#  'list',
#  'willing',
#  'defined',
#  'availability',
#  'academic',
#  'engagement',
#  'recruitment',
#  'mentor',
#  'prepares',
#  'functionality',
#  'recruiting',
#  'industries',
#  'architect',
#  'input',
#  'serves',
#  'opportunityaffirmative',
#  'improving',
#  'form',
#  'drawings',
#  'outstanding',
#  'behavior',
#  'difference',
#  'oversight',
#  'recommend',
#  'emerging',
#  'fun',
#  'scalable',
#  'units',
#  'internet',
#  'eeo',
#  'monitors',
#  'clean',
#  'mathematics',
#  'centers',
#  'tool',
#  'interfaces',
#  'study',
#  'competencies',
#  'judgment',
#  ...]

# %%
def example(arr,vocab):
    ind = sorted(range(len(arr)), key=lambda i: arr[i])[-100:]
    ans = []
    for i in ind:
        ans.append(vocab[i])
    return ans

def make_topic_word(vocab):
     return udf(lambda arr: example(arr, vocab))

# %%
#udfSum = udf(lambda x: example(x), ArrayType(FloatType())) 
vector_udf = udf(lambda vector: vector.toArray().tolist(),ArrayType(DoubleType()))
df = dataset.withColumn("position_array", vector_udf(dataset.features)) 
df.show(5)
df.printSchema()
# Out:
# +----------------+--------------------+-----------------------+--------------------+--------------------+--------------------+
# |             _id|           job_title|job_description_cleaned|                  tf|            features|      position_array|
# +----------------+--------------------+-----------------------+--------------------+--------------------+--------------------+
# |000004eaddcb4ae7|Research Account ...|   [current, employe...|(65536,[0,1,5,7,1...|(65536,[0,1,5,7,1...|[0.28210629980809...|
# |000016cd690914cd|Recruitment Coord...|   [temporaryrespons...|(65536,[1,4,9,12,...|(65536,[1,4,9,12,...|[0.0, 0.369906709...|
# |0000c4848b2b952d|Electrical Contro...|   [yearsr, electric...|(65536,[0,1,2,3,4...|(65536,[0,1,2,3,4...|[0.14105314990404...|
# |0000ef8321b7ed98|Product Developme...|   [like, join, fort...|(65536,[0,1,2,3,4...|(65536,[0,1,2,3,4...|[0.14105314990404...|
# |00010db38efb0901| Systems Engineer II|   [overview, new, i...|(65536,[0,1,2,4,8...|(65536,[0,1,2,4,8...|[0.56421259961619...|
# +----------------+--------------------+-----------------------+--------------------+--------------------+--------------------+
# only showing top 5 rows
#
# root
#  |-- _id: string (nullable = true)
#  |-- job_title: string (nullable = true)
#  |-- job_description_cleaned: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- tf: vector (nullable = true)
#  |-- features: vector (nullable = true)
#  |-- position_array: array (nullable = true)
#  |    |-- element: double (containsNull = true)

# %%
words_udf = udf(lambda arr: example(arr,vectorizers[0].vocabulary),ArrayType(StringType()))
df2 = df.withColumn("imp_words",make_topic_word(vectorizers[0].vocabulary)(df.position_array))
df2.show(5)
# Out:
# +----------------+--------------------+-----------------------+--------------------+--------------------+--------------------+--------------------+
# |             _id|           job_title|job_description_cleaned|                  tf|            features|      position_array|           imp_words|
# +----------------+--------------------+-----------------------+--------------------+--------------------+--------------------+--------------------+
# |000004eaddcb4ae7|Research Account ...|   [current, employe...|(65536,[0,1,5,7,1...|(65536,[0,1,5,7,1...|[0.28210629980809...|[report, performi...|
# |000016cd690914cd|Recruitment Coord...|   [temporaryrespons...|(65536,[1,4,9,12,...|(65536,[1,4,9,12,...|[0.0, 0.369906709...|[type, full, qual...|
# |0000c4848b2b952d|Electrical Contro...|   [yearsr, electric...|(65536,[0,1,2,3,4...|(65536,[0,1,2,3,4...|[0.14105314990404...|[degree, requirem...|
# |0000ef8321b7ed98|Product Developme...|   [like, join, fort...|(65536,[0,1,2,3,4...|(65536,[0,1,2,3,4...|[0.14105314990404...|[judgment, differ...|
# |00010db38efb0901| Systems Engineer II|   [overview, new, i...|(65536,[0,1,2,4,8...|(65536,[0,1,2,4,8...|[0.56421259961619...|[standards, mecha...|
# +----------------+--------------------+-----------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 5 rows

# %%
df2.printSchema()
# Out:
# root
#  |-- _id: string (nullable = true)
#  |-- job_title: string (nullable = true)
#  |-- job_description_cleaned: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- tf: vector (nullable = true)
#  |-- features: vector (nullable = true)
#  |-- position_array: array (nullable = true)
#  |    |-- element: double (containsNull = true)
#  |-- imp_words: string (nullable = true)

# %%
df2.select('_id','imp_words').write.format("com.mongodb.spark.sql.DefaultSource").mode("append").option("uri","mongodb://user:indeedjob@ec2-52-55-205-188.compute-1.amazonaws.com/appDatabase.jobs2").save()

# %%
(trainingData, testData) = dataset.randomSplit([0.7, 0.3], seed = 100)
#print("Training Dataset Count: " + str(trainingData.count()))
#print("Test Dataset Count: " + str(testData.count()))

# %%
lr = LogisticRegression(maxIter=20, regParam=0.3, elasticNetParam=0)
lrModel = lr.fit(trainingData)
predictions = lrModel.transform(testData)
#predictions.filter(predictions['prediction'] == 0) \
    #.select("job_description_cleaned","job_title","probability","label","prediction") \
    #.orderBy("probability", ascending=False) \
    #.show(n = 10, truncate = 30)

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
evaluator = MulticlassClassificationEvaluator(predictionCol="prediction")
evaluator.evaluate(predictions)

# %%
k = [2,10,5,15,6]
sorted(range(len(k)), key=lambda i: k[i])[-3:]
